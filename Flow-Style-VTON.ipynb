# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2024-06-29 10:00:16--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146836934 (140M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 140.03M   255MB/s    in 0.5s
#
# 2024-06-29 10:00:17 (255 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [146836934/146836934]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# !nvidia-smi
# Out:
# Sat Jun 29 10:00:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0              24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !git clone https://github.com/Lseoksee/Flow-Style-VTON.git
# Out:
# Cloning into 'Flow-Style-VTON'...
# remote: Enumerating objects: 375, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 375 (delta 68), reused 46 (delta 45), pack-reused 279
# Receiving objects: 100% (375/375), 5.74 MiB | 26.48 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
# !unzip /content/drive/MyDrive/VITON_traindata.zip -d /content/Flow-Style-VTON/train/dataset
# !cp /content/drive/MyDrive/vgg19-dcbb9e9d.pth  /content/Flow-Style-VTON/train/models/vgg19-dcbb9e9d.pth
# %cd Flow-Style-VTON
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/Flow-Style-VTON/train/dataset/__MACOSX/VITON_traindata/train_pose/._018350_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/VITON_traindata/train_pose/016082_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/__MACOSX/VITON_traindata/train_pose/._016082_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/VITON_traindata/train_pose/014969_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/__MACOSX/VITON_traindata/train_pose/._014969_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/VITON_traindata/train_pose/009707_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/__MACOSX/VITON_traindata/train_pose/._009707_0_keypoints.json
#   inflating: /content/Flow-Style-VTON/train/dataset/VITON_traindata/train_pose/014957_0_keypoints.json
# ...

# %%
# !conda create --prefix .conda python=3.6.13
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /content/Flow-Style-VTON/.conda
#
#   added / updated specs:
#     - python=3.6.13
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2021.5.30          |   py36h06a4308_0         139 KB
#     libffi-3.3                 |       he6710b0_2          50 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-21.2.2                 |   py36h06a4308_0         1.8 MB
#     python-3.6.13              |       h12debd9_1        32.5 MB
#     setuptools-58.0.4          |   py36h06a4308_0         788 KB
#     wheel-0.37.1               |     pyhd3eb1b0_0          33 KB
#     ------------------------------------------------------------
#                                            Total:        39.0 MB
#
# ...

# %%
# !source activate /content/Flow-Style-VTON/.conda && conda install pytorch==1.1.0 torchvision==0.3.0 tensorboardX opencv cudatoolkit=10.0 -c pytorch
# Out:
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /content/Flow-Style-VTON/.conda
#
#   added / updated specs:
#     - cudatoolkit=10.0
#     - opencv
#     - pytorch==1.1.0
#     - tensorboardx
#     - torchvision==0.3.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     cairo-1.16.0               |       hb05425b_5         1.2 MB
#     cffi-1.14.6                |   py36h400218f_0         220 KB
#     cudatoolkit-10.0.130       |                0       261.2 MB
#     cudnn-7.6.5                |       cuda10.0_0       165.0 MB
#     ffmpeg-4.0                 |       hcdf2ecd_0        53.3 MB
#     fontconfig-2.14.1          |       h4c34cd2_2         281 KB
#     freeglut-3.4.0             |       h6a678d5_0         160 KB
# ...

# %%
# %cd train
# Out:
# /content/Flow-Style-VTON/train

# %%
# !source activate /content/Flow-Style-VTON/.conda && sh scripts/train_PBAFN_stage1_fs.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: None
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: checkpoints_fs
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 100
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1_fs
# ndf: 64
# netG: global
# ngf: 64
# niter: 10
# niter_decay: 10
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
# !source activate /content/Flow-Style-VTON/.conda && sh scripts/train_PBAFN_e2e_fs.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: checkpoints_fs/PBAFN_stage1_fs/PBAFN_warp_epoch_101.pth
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: None
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: checkpoints_fs
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 100
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_e2e_fs
# ndf: 64
# netG: global
# ngf: 64
# niter: 10
# niter_decay: 10
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# ...

# %%
# !source activate /content/Flow-Style-VTON/.conda && sh scripts/train_PFAFN_stage1_fs.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: checkpoints_fs/PBAFN_e2e_fs/PBAFN_gen_epoch_101.pth
# PBAFN_warp_checkpoint: checkpoints_fs/PBAFN_e2e_fs/PBAFN_warp_epoch_101.pth
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: None
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: checkpoints_fs
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 100
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 3e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PFAFN_stage1_fs
# ndf: 64
# netG: global
# ngf: 64
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# ...

# %%
# !source activate /content/Flow-Style-VTON/.conda &&sh scripts/train_PFAFN_e2e_fs.sh

# %%
while True:
  pass
